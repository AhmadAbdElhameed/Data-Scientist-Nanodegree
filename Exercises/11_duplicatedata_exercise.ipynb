# %% [markdown]
# # Duplicate Data
#
# A data set might have duplicate data: in other words, the same record is represented multiple times. Sometimes, it's easy to find and eliminate duplicate data like when two records are exactly the same. At other times, like what was discussed in the video, duplicate data is hard to spot.
#
# # Exercise 1
#
# From the World Bank GDP data, count the number of countries that have had a project totalamt greater than 1 billion dollars (1,000,000,000). To get the count, you'll have to remove duplicate data rows.

# %%
import pandas as pd

# read in the projects data set and do some basic wrangling 
projects = pd.read_csv('../data/projects_data.csv', dtype=str)
projects.drop('Unnamed: 56', axis=1, inplace=True)
projects['totalamt'] = pd.to_numeric(projects['totalamt'].str.replace(',', ''))
projects['countryname'] = projects['countryname'].str.split(';', expand=True)[0]
projects['boardapprovaldate'] = pd.to_datetime(projects['boardapprovaldate'])

# TODO: filter the data frame for projects over 1 billion dollars
projects_billion = projects[projects['totalamt'] > 1000000000]
print(projects_billion.shape)
# TODO: count the number of unique countries in the results
projects_billion["countryname"].nunique()
# Out:
# (44, 56)
# 17

# %%
projects.shape
# Out:
# (18248, 56)

# %%
projects.drop_duplicates(inplace=True)

# %%
projects.shape
# Out:
# (18248, 56)

# %%
projects_billion.head()
# Out:
#            id                    regionname             countryname prodline  \
# 304   P164079  Middle East and North Africa  Arab Republic of Egypt       PE
# 816   P161167  Middle East and North Africa        Republic of Iraq       PE
# 1210  P154981   Latin America and Caribbean        Republic of Peru       PE
# 1211  P156858   Latin America and Caribbean        Republic of Peru       PE
# 1260  P155962  Middle East and North Africa        Republic of Iraq       PE
#
#                     lendinginstr lendinginstrtype envassesmentcategorycode  \
# 304   Development Policy Lending               AD                      NaN
# 816   Development Policy Lending               AD                      NaN
# 1210  Development Policy Lending               AD                      NaN
# 1211  Development Policy Lending               AD                      NaN
# 1260  Development Policy Lending               AD                      NaN
#
#      supplementprojectflg productlinetype projectstatusdisplay   ...    \
# 304                     N               L               Active   ...
# 816                     N               L               Closed   ...
# 1210                    N               L               Active   ...
# 1211                    N               L               Active   ...
# 1260                    N               L               Closed   ...
#
#      mjtheme2name mjtheme3name mjtheme4name mjtheme5name location GeoLocID  \
# 304           NaN          NaN          NaN          NaN      NaN      NaN
# 816           NaN          NaN          NaN          NaN      NaN      NaN
# 1210          NaN          NaN          NaN          NaN      NaN      NaN
# 1211          NaN          NaN          NaN          NaN      NaN      NaN
# 1260          NaN          NaN          NaN          NaN      NaN      NaN
#
#      GeoLocName Latitude  Longitude Country
# 304         NaN      NaN        NaN     NaN
# 816         NaN      NaN        NaN     NaN
# 1210        NaN      NaN        NaN     NaN
# 1211        NaN      NaN        NaN     NaN
# 1260        NaN      NaN        NaN     NaN
#
# [5 rows x 56 columns]

# %% [markdown]
# # Exercise 2 (challenge)
#
# This exercise is more challenging. The projects data set contains data about Yugoslavia, which was an Eastern European country until 1992. Yugoslavia eventually broke up into 7 countries: Bosnia and Herzegovina, Croatia, Kosovo, Macedonia, Montenegro, Serbia, and Slovenia.
#
# But the projects dataset has some ambiguity in how it treats Yugoslavia and the 7 countries that came from Yugoslavia. Your task is to find Yugoslavia projects that are probably represented multiple times in the data set.

# %%
projects_billion.countryname
# Out:
# 304               Arab Republic of Egypt
# 816                     Republic of Iraq
# 1210                    Republic of Peru
# 1211                    Republic of Peru
# 1260                    Republic of Iraq
# 1268                   Republic of India
# 2034                             Romania
# 2051                   Republic of India
# 2104                   Republic of India
# 2530                  Republic of Poland
# 2990                             Romania
# 3037               Republic of Indonesia
# 3066              Republic of Kazakhstan
# 3486                  Republic of Poland
# 3727     People's Republic of Bangladesh
# 3812                   Republic of India
# 3891               United Mexican States
# 4037       Federative Republic of Brazil
# 4113                  Republic of Poland
# 4282            Republic of South Africa
# 4335               United Mexican States
# 4340                  Republic of Turkey
# 4507               United Mexican States
# 4554               United Mexican States
# 4587                   Republic of India
# 4591                             Hungary
# 4594                   Republic of India
# 4697                  Republic of Poland
# 4848              Republic of Kazakhstan
# 4882               United Mexican States
# 4936       Federative Republic of Brazil
# 4941               Republic of Indonesia
# 5018                  Republic of Poland
# 5086               United Mexican States
# 5199       Federative Republic of Brazil
# 7967                  Republic of Turkey
# 8155                  Republic of Turkey
# 9053                  Argentine Republic
# 9063                   Republic of Korea
# 9102                  Russian Federation
# 9258                   Republic of Korea
# 9325                   Republic of Korea
# 11540              United Mexican States
# 16052                  Republic of India
# Name: countryname, dtype: object

# %%
# TODO: output all projects for the 'Socialist Federal Republic of Yugoslavia'
# HINT: You can use the exact country name or use the pandas str.contains() method to search for Yugoslavia
projects_billion["countryname"].str.contains("Yugoslavia")
# Out:
# 304      False
# 816      False
# 1210     False
# 1211     False
# 1260     False
# 1268     False
# 2034     False
# 2051     False
# 2104     False
# 2530     False
# 2990     False
# 3037     False
# 3066     False
# 3486     False
# 3727     False
# 3812     False
# 3891     False
# 4037     False
# 4113     False
# 4282     False
# 4335     False
# 4340     False
# 4507     False
# 4554     False
# 4587     False
# 4591     False
# 4594     False
# 4697     False
# 4848     False
# 4882     False
# 4936     False
# 4941     False
# 5018     False
# 5086     False
# 5199     False
# 7967     False
# 8155     False
# 9053     False
# 9063     False
# 9102     False
# 9258     False
# 9325     False
# 11540    False
# 16052    False
# Name: countryname, dtype: bool

# %% [markdown]
# Yugoslavia officially ended on [April 27th, 1992](https://en.wikipedia.org/wiki/Yugoslavia).
#
# In the code cell below, filter for projects with a 'boardapprovaldate' prior to April 27th, 1992 **and** with 'countryname' Bosnia and Herzegovina, Croatia, Kosovo, Macedonia, Serbia **or** Slovenia. You'll see there are a total of 12 projects in the data set that match this criteria. Save the results in the republics variable

# %%
import datetime

# TODO: filter the projects data set for project boardapprovaldate prior to April 27th, 1992 AND with countryname
#  of either 'Bosnia and Herzegovina', 'Croatia', 'Kosovo', 'Macedonia', 'Serbia', or 'Sovenia'. Store the
#  results in the republics variable
#
#  TODO: so that it's easier to see all the data, keep only these columns:
# ['regionname', 'countryname', 'lendinginstr', 'totalamt', 'boardapprovaldate',
# 'location','GeoLocID', 'GeoLocName', 'Latitude','Longitude','Country', 'project_name']

# TODO: sort the results by boardapprovaldate

republics = projects[(projects["boardapprovaldate"] < datetime.date(1992,4,27)) & 
                    ((projects['countryname'].str.contains("Bosnia")) |
                    (projects['countryname'].str.contains("Montenegro")) |
                    (projects['countryname'].str.contains("Croatia")) |
                    (projects['countryname'].str.contains("Kosovo")) |
                    (projects['countryname'].str.contains("Macedonia")) |
                    (projects['countryname'].str.contains("Serbia")) |
                    (projects['countryname'].str.contains("Sovenia")))].sort_values('boardapprovaldate')


# show the results
republics
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   del sys.path[0]
#             id               regionname             countryname prodline  \
# 13973  P009174  Europe and Central Asia               Macedonia       PE
# 13048  P038998  Europe and Central Asia  Bosnia and Herzegovina       PE
# 13049  P038999  Europe and Central Asia     Republic of Croatia       PE
# 13050  P039000  Europe and Central Asia               Macedonia       PE
# 12228  P038997  Europe and Central Asia     Republic of Croatia       PE
# 12061  P039258  Europe and Central Asia     Republic of Croatia       PE
# 12062  P039260  Europe and Central Asia     Republic of Croatia       PE
# 12063  P039261  Europe and Central Asia  Bosnia and Herzegovina       PE
# 11696  P039002  Europe and Central Asia     Republic of Croatia       PE
#
#                                  lendinginstr lendinginstrtype  \
# 13973                Specific Investment Loan               IN
# 13048                Specific Investment Loan               IN
# 13049                Specific Investment Loan               IN
# 13050                Specific Investment Loan               IN
# 12228             Financial Intermediary Loan               IN
# 12061  Sector Investment and Maintenance Loan               IN
# 12062  Sector Investment and Maintenance Loan               IN
# 12063  Sector Investment and Maintenance Loan               IN
# 11696                Specific Investment Loan               IN
#
#       envassesmentcategorycode supplementprojectflg productlinetype  \
# 13973                        C                    N               L
# 13048                        C                    Y               L
# 13049                        C                    Y               L
# 13050                        C                    Y               L
# 12228                        C                    Y               L
# 12061                      NaN                    Y               L
# 12062                      NaN                    Y               L
# 12063                        C                    Y               L
# 11696                        C                    N               L
#
#       projectstatusdisplay   ...   mjtheme2name mjtheme3name mjtheme4name  \
# 13973               Closed   ...            NaN          NaN          NaN
# 13048               Closed   ...            NaN          NaN          NaN
# 13049               Closed   ...            NaN          NaN          NaN
# 13050               Closed   ...            NaN          NaN          NaN
# 12228               Closed   ...            NaN          NaN          NaN
# 12061               Closed   ...            NaN          NaN          NaN
# 12062               Closed   ...            NaN          NaN          NaN
# 12063               Closed   ...            NaN          NaN          NaN
# 11696               Closed   ...            NaN          NaN          NaN
#
#       mjtheme5name location GeoLocID GeoLocName Latitude  Longitude Country
# 13973          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13048          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13049          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13050          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 12228          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 12061          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 12062          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 12063          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 11696          NaN      NaN      NaN        NaN      NaN        NaN     NaN
#
# [9 rows x 56 columns]

# %% [markdown]
# Are these projects also represented in the data labeled Yugoslavia? In the code cell below, filter for Yugoslavia projects approved between February 1st, 1980 and May 23rd, 1989 which are the minimum and maximum dates in the results above. Store the results in the yugoslavia variable.
#
# The goal is to see if there are any projects represented more than once in the data set.

# %%
# TODO: Filter the projects data for Yugoslavia projects between
# February 1st, 1980 and May 23rd, 1989. Store the results in the
# Yugoslavia variable. Keep the same columns as the previous code cell.
# Sort the values by boardapprovaldate

yugoslavia = projects[(projects['countryname'].str.contains('Yugoslavia')) & 
         (projects['boardapprovaldate'] >= datetime.date(1980, 2, 1)) &
         (projects['boardapprovaldate'] <= datetime.date(1989, 5, 23))].sort_values('boardapprovaldate')
yugoslavia
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   import sys
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#             id               regionname  \
# 13966  P009186  Europe and Central Asia
# 13937  P009188  Europe and Central Asia
# 13773  P009194  Europe and Central Asia
# 13706  P009192  Europe and Central Asia
# 13647  P009195  Europe and Central Asia
# 13629  P009193  Europe and Central Asia
# 13555  P009196  Europe and Central Asia
# 13526  P009200  Europe and Central Asia
# 13412  P009199  Europe and Central Asia
# 13402  P009197  Europe and Central Asia
# 13365  P009198  Europe and Central Asia
# 13231  P009204  Europe and Central Asia
# 13099  P009202  Europe and Central Asia
# 13098  P009201  Europe and Central Asia
# 13071  P009203  Europe and Central Asia
# 13053  P009209  Europe and Central Asia
# 13046  P009206  Europe and Central Asia
# 13047  P009208  Europe and Central Asia
# 13041  P009207  Europe and Central Asia
# 12809  P009210  Europe and Central Asia
# 12677  P009214  Europe and Central Asia
# 12671  P009205  Europe and Central Asia
# 12617  P009211  Europe and Central Asia
# 12577  P009212  Europe and Central Asia
# 12375  P009215  Europe and Central Asia
# 12227  P038996  Europe and Central Asia
# 12225  P009217  Europe and Central Asia
# 12060  P009265  Europe and Central Asia
# 11866  P009242  Europe and Central Asia
# 11695  P009275  Europe and Central Asia
# 11694  P009225  Europe and Central Asia
#
#                                     countryname prodline  \
# 13966  Socialist Federal Republic of Yugoslavia       PE
# 13937  Socialist Federal Republic of Yugoslavia       PE
# 13773  Socialist Federal Republic of Yugoslavia       PE
# 13706  Socialist Federal Republic of Yugoslavia       PE
# 13647  Socialist Federal Republic of Yugoslavia       PE
# 13629  Socialist Federal Republic of Yugoslavia       PE
# 13555  Socialist Federal Republic of Yugoslavia       PE
# 13526  Socialist Federal Republic of Yugoslavia       PE
# 13412  Socialist Federal Republic of Yugoslavia       PE
# 13402  Socialist Federal Republic of Yugoslavia       PE
# 13365  Socialist Federal Republic of Yugoslavia       PE
# 13231  Socialist Federal Republic of Yugoslavia       PE
# 13099  Socialist Federal Republic of Yugoslavia       PE
# 13098  Socialist Federal Republic of Yugoslavia       PE
# 13071  Socialist Federal Republic of Yugoslavia       PE
# 13053  Socialist Federal Republic of Yugoslavia       PE
# 13046  Socialist Federal Republic of Yugoslavia       PE
# 13047  Socialist Federal Republic of Yugoslavia       PE
# 13041  Socialist Federal Republic of Yugoslavia       PE
# 12809  Socialist Federal Republic of Yugoslavia       PE
# 12677  Socialist Federal Republic of Yugoslavia       PE
# 12671  Socialist Federal Republic of Yugoslavia       PE
# 12617  Socialist Federal Republic of Yugoslavia       PE
# 12577  Socialist Federal Republic of Yugoslavia       PE
# 12375  Socialist Federal Republic of Yugoslavia       PE
# 12227  Socialist Federal Republic of Yugoslavia       PE
# 12225  Socialist Federal Republic of Yugoslavia       PE
# 12060  Socialist Federal Republic of Yugoslavia       PE
# 11866  Socialist Federal Republic of Yugoslavia       PE
# 11695  Socialist Federal Republic of Yugoslavia       PE
# 11694  Socialist Federal Republic of Yugoslavia       PE
#
#                                  lendinginstr lendinginstrtype  \
# 13966             Financial Intermediary Loan               IN
# 13937                Specific Investment Loan               IN
# 13773             Financial Intermediary Loan               IN
# 13706             Financial Intermediary Loan               IN
# 13647                Specific Investment Loan               IN
# 13629             Financial Intermediary Loan               IN
# 13555             Financial Intermediary Loan               IN
# 13526                Specific Investment Loan               IN
# 13412             Financial Intermediary Loan               IN
# 13402                Specific Investment Loan               IN
# 13365                Specific Investment Loan               IN
# 13231                Specific Investment Loan               IN
# 13099             Financial Intermediary Loan               IN
# 13098             Financial Intermediary Loan               IN
# 13071              Structural Adjustment Loan               AD
# 13053  Sector Investment and Maintenance Loan               IN
# 13046             Financial Intermediary Loan               IN
# 13047                Specific Investment Loan               IN
# 13041                Specific Investment Loan               IN
# 12809             Financial Intermediary Loan               IN
# 12677                Specific Investment Loan               IN
# 12671                  Sector Adjustment Loan               AD
# 12617                Specific Investment Loan               IN
# 12577                Specific Investment Loan               IN
# 12375  Sector Investment and Maintenance Loan               IN
# 12227             Financial Intermediary Loan               IN
# 12225             Financial Intermediary Loan               IN
# 12060  Sector Investment and Maintenance Loan               IN
# 11866             Financial Intermediary Loan               IN
# 11695                Specific Investment Loan               IN
# 11694  Sector Investment and Maintenance Loan               IN
#
#       envassesmentcategorycode supplementprojectflg productlinetype  \
# 13966                      NaN                    N               L
# 13937                      NaN                    N               L
# 13773                      NaN                    N               L
# 13706                      NaN                    N               L
# 13647                      NaN                    N               L
# 13629                      NaN                    N               L
# 13555                      NaN                    N               L
# 13526                      NaN                    N               L
# 13412                      NaN                    N               L
# 13402                      NaN                    N               L
# 13365                      NaN                    N               L
# 13231                      NaN                    N               L
# 13099                      NaN                    N               L
# 13098                      NaN                    N               L
# 13071                      NaN                    N               L
# 13053                        C                    N               L
# 13046                      NaN                    N               L
# 13047                        C                    N               L
# 13041                      NaN                    N               L
# 12809                      NaN                    N               L
# 12677                      NaN                    N               L
# 12671                      NaN                    N               L
# 12617                      NaN                    N               L
# 12577                        C                    N               L
# 12375                        C                    N               L
# 12227                        C                    Y               L
# 12225                        C                    N               L
# 12060                        C                    N               L
# 11866                        C                    N               L
# 11695                      NaN                    N               L
# 11694                        C                    N               L
#
#       projectstatusdisplay   ...   mjtheme2name mjtheme3name mjtheme4name  \
# 13966               Closed   ...            NaN          NaN          NaN
# 13937               Closed   ...            NaN          NaN          NaN
# 13773               Closed   ...            NaN          NaN          NaN
# 13706               Closed   ...            NaN          NaN          NaN
# 13647               Closed   ...            NaN          NaN          NaN
# 13629               Closed   ...            NaN          NaN          NaN
# 13555               Closed   ...            NaN          NaN          NaN
# 13526               Closed   ...            NaN          NaN          NaN
# 13412               Closed   ...            NaN          NaN          NaN
# 13402               Closed   ...            NaN          NaN          NaN
# 13365               Closed   ...            NaN          NaN          NaN
# 13231               Closed   ...            NaN          NaN          NaN
# 13099               Closed   ...            NaN          NaN          NaN
# 13098               Closed   ...            NaN          NaN          NaN
# 13071               Closed   ...            NaN          NaN          NaN
# 13053               Closed   ...            NaN          NaN          NaN
# 13046               Closed   ...            NaN          NaN          NaN
# 13047               Closed   ...            NaN          NaN          NaN
# 13041               Closed   ...            NaN          NaN          NaN
# 12809               Closed   ...            NaN          NaN          NaN
# 12677               Closed   ...            NaN          NaN          NaN
# 12671               Closed   ...            NaN          NaN          NaN
# 12617               Closed   ...            NaN          NaN          NaN
# 12577               Closed   ...            NaN          NaN          NaN
# 12375               Closed   ...            NaN          NaN          NaN
# 12227               Closed   ...            NaN          NaN          NaN
# 12225               Closed   ...            NaN          NaN          NaN
# 12060               Closed   ...            NaN          NaN          NaN
# 11866               Closed   ...            NaN          NaN          NaN
# 11695               Closed   ...            NaN          NaN          NaN
# 11694               Closed   ...            NaN          NaN          NaN
#
#       mjtheme5name location GeoLocID GeoLocName Latitude  Longitude Country
# 13966          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13937          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13773          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13706          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13647          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13629          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13555          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13526          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13412          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13402          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13365          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13231          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13099          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13098          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13071          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13053          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13046          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13047          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 13041          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 12809          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 12677          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 12671          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 12617          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 12577          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 12375          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 12227          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 12225          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 12060          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 11866          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 11695          NaN      NaN      NaN        NaN      NaN        NaN     NaN
# 11694          NaN      NaN      NaN        NaN      NaN        NaN     NaN
#
# [31 rows x 56 columns]

# %%
yugoslavia.shape
# Out:
# (31, 12)

# %%
republics.shape
# Out:
# (9, 56)

# %% [markdown]
# And as a final step, try to see if there are any projects in the republics variable and yugoslavia variable that could be the same project.
#
# There are multiple ways to do that. As a suggestion, find unique dates in the republics variable. Then separately find unique dates in the yugoslavia variable. Concatenate (ie append) the results together. And then count the number of times each date occurs in this list. If a date occurs twice, that means the same boardapprovaldate appeared in both the Yugoslavia data as well as in the republics data.
#
# You should find that there are four suspicious cases:
#
# * July 26th, 1983
# * March 31st, 1987
# * October 13th, 1987
# * May 23rd, 1989

# %%
from collections import Counter

# %%
import numpy as np

# TODO: find the unique dates in the republics variable
republic_unique_dates = republics.boardapprovaldate.unique()

# TODO: find the unique dates in the yugoslavia variable
yugoslavia_unique_dates = yugoslavia.boardapprovaldate.unique()

# TODO: make a list of the results appending one list to the other
dates = np.append(republic_unique_dates,yugoslavia_unique_dates,axis=0)

# TODO: print out the dates that appeared twice in the results

# %%
vals , indices = np.unique(dates, return_index=True)

# %%
vals.shape
# Out:
# (28,)

# %%
vals
# Out:
# array(['1980-02-01T00:00:00.000000000', '1980-02-26T00:00:00.000000000',
#        '1980-03-25T00:00:00.000000000', '1980-10-28T00:00:00.000000000',
#        '1981-03-03T00:00:00.000000000', '1981-04-28T00:00:00.000000000',
#        '1981-05-14T00:00:00.000000000', '1981-07-14T00:00:00.000000000',
#        '1981-11-10T00:00:00.000000000', '1982-04-27T00:00:00.000000000',
#        '1982-05-04T00:00:00.000000000', '1982-05-27T00:00:00.000000000',
#        '1983-01-25T00:00:00.000000000', '1983-06-09T00:00:00.000000000',
#        '1983-06-28T00:00:00.000000000', '1983-07-19T00:00:00.000000000',
#        '1983-07-26T00:00:00.000000000', '1983-08-02T00:00:00.000000000',
#        '1984-07-31T00:00:00.000000000', '1985-04-30T00:00:00.000000000',
#        '1985-05-03T00:00:00.000000000', '1985-06-06T00:00:00.000000000',
#        '1985-06-27T00:00:00.000000000', '1986-06-10T00:00:00.000000000',
#        '1987-03-31T00:00:00.000000000', '1987-10-13T00:00:00.000000000',
#        '1988-06-29T00:00:00.000000000', '1989-05-23T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
for i in range(len(vals)):
    if indices[i] == 2:
        print(vals[i])
# Out:
# 1987-03-31T00:00:00.000000000

# %% [markdown]
# # Conclusion
#
# On July 26th, 1983, for example, projects were approved for Bosnia and Herzegovina, Croatia, Macedonia, Slovenia, and Yugoslavia. The code below shows the projects for that date. You'll notice that Yugoslavia had two projects, one of which was called "Power Transmission Project (03) Energy Managem...". The projects in the other countries were all called "POWER TRANS.III".
#
# This looks like a case of duplicate data. What you end up doing with this knowledge would depend on the context. For example, if you wanted to get a true count for the total number of projects in the data set, should all of these projects be counted as one project?
#
# Run the code cell below to see the projects in question.

# %%
import datetime

# run this code cell to see the duplicate data
pd.concat([yugoslavia[yugoslavia['boardapprovaldate'] == datetime.date(1983, 7, 26)], republics[republics['boardapprovaldate'] == datetime.date(1983, 7, 26)]])
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and 'the values will not compare equal to the
# 'datetime.date'. To retain the current behavior, convert the
# 'datetime.date' to a datetime with 'pd.Timestamp'.
#   after removing the cwd from sys.path.
#             id               regionname  \
# 13046  P009206  Europe and Central Asia
# 13047  P009208  Europe and Central Asia
# 13048  P038998  Europe and Central Asia
# 13049  P038999  Europe and Central Asia
# 13050  P039000  Europe and Central Asia
#
#                                     countryname prodline  \
# 13046  Socialist Federal Republic of Yugoslavia       PE
# 13047  Socialist Federal Republic of Yugoslavia       PE
# 13048                    Bosnia and Herzegovina       PE
# 13049                       Republic of Croatia       PE
# 13050                                 Macedonia       PE
#
#                       lendinginstr lendinginstrtype envassesmentcategorycode  \
# 13046  Financial Intermediary Loan               IN                      NaN
# 13047     Specific Investment Loan               IN                        C
# 13048     Specific Investment Loan               IN                        C
# 13049     Specific Investment Loan               IN                        C
# 13050     Specific Investment Loan               IN                        C
#
#       supplementprojectflg productlinetype projectstatusdisplay   ...    \
# 13046                    N               L               Closed   ...
# 13047                    N               L               Closed   ...
# 13048                    Y               L               Closed   ...
# 13049                    Y               L               Closed   ...
# 13050                    Y               L               Closed   ...
#
#       mjtheme2name mjtheme3name mjtheme4name mjtheme5name location GeoLocID  \
# 13046          NaN          NaN          NaN          NaN      NaN      NaN
# 13047          NaN          NaN          NaN          NaN      NaN      NaN
# 13048          NaN          NaN          NaN          NaN      NaN      NaN
# 13049          NaN          NaN          NaN          NaN      NaN      NaN
# 13050          NaN          NaN          NaN          NaN      NaN      NaN
#
#       GeoLocName Latitude  Longitude Country
# 13046        NaN      NaN        NaN     NaN
# 13047        NaN      NaN        NaN     NaN
# 13048        NaN      NaN        NaN     NaN
# 13049        NaN      NaN        NaN     NaN
# 13050        NaN      NaN        NaN     NaN
#
# [5 rows x 56 columns]
